# %%
from selenium import webdriver
driver = webdriver.Chrome('../../driver/chromedriver.exe')

# %%
driver.get('http://naver.com') #w ebdriver를 활용한 url접속하기

# %%
html = driver.page_source
html
# Out:
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="ko" class="svgless"><head>\n<meta charset="utf-8" />\n<meta name="Referrer" content="origin" />\n<meta http-equiv="Content-Script-Type" content="text/javascript" />\n<meta http-equiv="Content-Style-Type" content="text/css" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="viewport" content="width=1100" />\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow" />\n<meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" />\n<meta property="og:title" content="네이버" />\n<meta property="og:url" content="http://www.naver.com/" />\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" />\n<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:title" content="" />\n<meta name="twitter:url" cont
# ...

# %%
driver.save_screenshot('001.jpg') #스크린샷 찍기
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:1007: UserWarning: name used for saved screenshot does not match file type. It should end with a `.png` extension
#   "type. It should end with a `.png` extension", UserWarning)
# True

# %%
elem_login = driver.find_element_by_id("id")
elem_login.clear()
elem_login.send_keys('seoyj0330')   #()안에 본인의 아이디가 들어가면 됨

elem_login = driver.find_element_by_id("pw")
elem_login.clear()
elem_login.send_keys('nvq9ne')  #()안에 자신의 패스워드

# %%
# XPath
# javascript를 활용하기 위한 웹페이지 내용을 xml형식으로 보여준다
xpath = """//*[@id="frmNIDLogin"]/fieldset/span/input"""   # xpath copy를 복사하여 문자열로
driver.find_element_by_xpath(xpath).click()

# %%
#메일 찾아 들어가기
driver.get("http://mail.naver.com")

# %%
from bs4 import BeautifulSoup

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

raw_list = soup.find_all('div', 'name _ccr(lst.from) ')
raw_list
# Out:
# [<div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|5022) _stopDefault" href="#" title='"사람인 | 아바타" &lt;avatar_matching@mailinfo.saramin.co.kr&gt;'>사람인 | 아바타</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|5021) _stopDefault" href="#" title='"사람인 | 맞춤채용" &lt;personalmatching@mailinfo.saramin.co.kr&gt;'>사람인 | 맞춤채용</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|5020) _stopDefault" href="#" title='"사람인 | 아바타" &lt;avatarmatching@mailinfo.saramin.co.kr&gt;'>사람인 | 아바타</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|5019) _stopDefault" href="#" title='"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" &lt;navercafe@naver.com&gt;'>스펙업 | 대학생,대외..</a></div>,
# ...

# %%
send_list = [raw_list[n].find('a').get_text() for n in range(0, len(raw_list))]
send_list
# Out:
# ['사람인 | 아바타',
#  '사람인 | 맞춤채용',
#  '사람인 | 아바타',
#  '스펙업 | 대학생,대외..',
#  '사람인 | 신입공채',
#  '스펙업 | 대학생,대외..',
#  '스펙업 | 대학생,대외..',
#  '스펙업 | 대학생,대외..',
#  '사람인 | 아바타',
#  '사람인 | 맞춤채용',
#  '사람인 | 신입공채',
#  '스펙업 | 대학생,대외..',
#  '사람인 | 아바타',
#  '사람인 | 신입공채',
#  '스펙업 | 대학생,대외..']

# %%
driver.close() #브라우저가 꺼짐

# %%
title=[raw_list[n].a['title'] for n in range(0, len(raw_list))]
title
# Out:
# ['"사람인 | 아바타" <avatar_matching@mailinfo.saramin.co.kr>',
#  '"사람인 | 맞춤채용" <personalmatching@mailinfo.saramin.co.kr>',
#  '"사람인 | 아바타" <avatarmatching@mailinfo.saramin.co.kr>',
#  '"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" <navercafe@naver.com>',
#  '"사람인 | 신입공채" <openrecruitmatching@mailinfo.saramin.co.kr>',
#  '"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" <navercafe@naver.com>',
#  '"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" <navercafe@naver.com>',
#  '"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" <navercafe@naver.com>',
#  '"사람인 | 아바타" <avatar_matching@mailinfo.saramin.co.kr>',
#  '"사람인 | 맞춤채용" <personalmatching@mailinfo.saramin.co.kr>',
#  '"사람인 | 신입공채" <openrecruitmatching@mailinfo.saramin.co.kr>',
#  '"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" <navercafe@naver.com>',
#  '"사람인 | 아바타" <avatarmatching@mailinfo.saramin.co.kr>',
#  '"사람인 | 신입공채" <openrecruitmatching@mailinfo.saramin.co.kr>',
#  '"스펙업 | 대학생,대외활동,공모전,알바,인턴,취업,NCS,자기소개" <navercafe@naver.com>']
